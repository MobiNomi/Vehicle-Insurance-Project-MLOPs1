# %%
import pandas as pd
import pymongo
 
df = pd.read_csv("data.csv")
df.head(10)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
# 5   6  Female   24                1         33.0                   0
# 6   7    Male   23                1         11.0                   0
# 7   8  Female   56                1         28.0                   0
# 8   9  Female   24                1          3.0                   1
# 9  10  Female   32                1          6.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# ...

# %%
# we will convert this data into json format and then we will insert this data into mongodb database.
# records is a list of dictionaries. Each dictionary is a record in the dataframe.
data = df.to_dict("records")

# %%
DB_name = "Proj1"
COLLECTION_NAME = "proj1-Data"
connection_url = "mongodb+srv://mubashir5001177_db_user:dGnSFbqgFeYxQYwq@cluster0.5ak9vdw.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(connection_url)
database = client[DB_name]
collection = database[COLLECTION_NAME]

# %%
# uploading the data to mongodb database
collection.insert_many(data)

# %%
import pymongo
import certifi

uri = "mongodb+srv://yourusername:yourpassword@cluster0.5ak9vdw.mongodb.net/?appName=Cluster0"

client = pymongo.MongoClient(uri, tlsCAFile=certifi.where())

try:
    client.admin.command('ping')
    print("✅ Connection successful!")
except Exception as e:
    print("❌ Connection failed:", e)
# Out:
# ✅ Connection successful!

# %%
collection.delete_many({})
# Out:
# DeleteResult({'n': 481109, 'electionId': ObjectId('7fffffff0000000000000280'), 'opTime': {'ts': Timestamp(1784020044, 721), 't': 640}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1784020044, 721), 'signature': {'hash': b'DH0\xce1\x82\x0c0Hw\x01\xa0\xd6^\x10E.H\t\x9a', 'keyId': 7606403737099173891}}, 'operationTime': Timestamp(1784020044, 721)}, acknowledged=True)

# %%
print(collection.count_documents({}))  # should print 0
# Out:
# 0

# %%
import pandas as pd

df = pd.read_csv("data.csv")  # or wherever your original source is
data = df.to_dict('records')

batch_size = 5000
for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    collection.insert_many(batch)
    print(f"Inserted {i + len(batch)} / {len(data)}")
# Out:
# Inserted 5000 / 381109
# Inserted 10000 / 381109
# Inserted 15000 / 381109
# Inserted 20000 / 381109
# Inserted 25000 / 381109
# Inserted 30000 / 381109
# Inserted 35000 / 381109
# Inserted 40000 / 381109
# Inserted 45000 / 381109
# Inserted 50000 / 381109
# Inserted 55000 / 381109
# Inserted 60000 / 381109
# Inserted 65000 / 381109
# Inserted 70000 / 381109
# Inserted 75000 / 381109
# Inserted 80000 / 381109
# Inserted 85000 / 381109
# Inserted 90000 / 381109
# Inserted 95000 / 381109
# Inserted 100000 / 381109
# Inserted 105000 / 381109
# Inserted 110000 / 381109
# Inserted 115000 / 381109
# Inserted 120000 / 381109
# Inserted 125000 / 381109
# Inserted 130000 / 381109
# Inserted 135000 / 381109
# Inserted 140000 / 381109
# Inserted 145000 / 381109
# Inserted 150000 / 381109
# Inserted 155000 / 381109
# Inserted 160000 / 381109
# Inserted 165000 / 381109
# Inserted 170000 / 381109
# Inserted 175000 / 381109
# Inserted 180000 / 381109
# Inserted 185000 / 381109
# ...

# %%
print(collection.count_documents({}))  # should be 381,109 (your original count)
# Out:
# 381109
